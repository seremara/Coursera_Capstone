# %% [markdown]
# # Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto
# Part2. Get Geodata and macth tables

# %%
# import libraries
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Step 1: get the data from Part 1

# %%
part1data = "TNTCityPart1.csv" # get data in csv form
TNTCityPC = pd.read_csv(part1data).set_index("Postcode")
TNTCityPC.rename_axis("Postal Code", axis='index', inplace=True)
TNTCityPC.head(15)
# Out:
#                  Borough                                      Neighbourhood
# Postal Code
# M1B          Scarborough                                     Malvern, Rouge
# M1C          Scarborough             Highland Creek, Port Union, Rouge Hill
# M1E          Scarborough                  Guildwood, Morningside, West Hill
# M1G          Scarborough                                             Woburn
# M1H          Scarborough                                          Cedarbrae
# M1J          Scarborough                                Scarborough Village
# M1K          Scarborough        East Birchmount Park, Ionview, Kennedy Park
# M1L          Scarborough                    Clairlea, Golden Mile, Oakridge
# M1M          Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# M1N          Scarborough                        Birch Cliff, Cliffside West
# M1P          Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# ...

# %% [markdown]
# # Step 2. Get Data from Geodata and join dataframes

# %%
# get data from Coursera csv

TNTGeoOutput = 'https://cocl.us/Geospatial_data'
# !wget -q -O 'toronto_m.geospatial_data.csv' TNTGeoOutput
geodf = pd.read_csv(TNTGeoOutput).set_index("Postal Code")

#join both dataframes
FinalTable = TNTCityPC.join(geodf)

# %% [markdown]
# # Step 3. Show table

# %%
FinalTable.head(20)
# Out:
#                  Borough                                      Neighbourhood  \
# Postal Code
# M1B          Scarborough                                     Malvern, Rouge
# M1C          Scarborough             Highland Creek, Port Union, Rouge Hill
# M1E          Scarborough                  Guildwood, Morningside, West Hill
# M1G          Scarborough                                             Woburn
# M1H          Scarborough                                          Cedarbrae
# M1J          Scarborough                                Scarborough Village
# M1K          Scarborough        East Birchmount Park, Ionview, Kennedy Park
# M1L          Scarborough                    Clairlea, Golden Mile, Oakridge
# M1M          Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# M1N          Scarborough                        Birch Cliff, Cliffside West
# M1P          Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# ...

# %% [markdown]
# Thank you for grading

# %% [markdown]
# See you in Part 3
